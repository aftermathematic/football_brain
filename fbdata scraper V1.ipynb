# %%
# Standard library imports
import os
import warnings
import requests
import time

# Miscellaneous settings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
comps = [
    'E0', 'E1', 'E2', 'E3',
    'SC0', 'SC1',
    'D1', 'D2',
    'F1', 'F2',
    'I1', 'I2',
    'SP1', 'SP2',
    'B1',
    'G1',
    'N1',
    'P1',
    'T1',
]

seasons = [
    #'2324', 
    #'2223', '2122', '2021',
    #'1920', '1819', '1718', '1617',
    '1516', '1415', '1314', '1213',
    '1112', '1011', 
    '0910', '0809',
    '0708', '0607', '0506', '0405',
    '0304', '0203', '0102', '0001',
]


countries = [
    "ARG", "AUT", "BRA", "CHN",
    "DNK", "FIN", "IRL", "JPN",
    "MEX", "NOR", "POL", "ROU",
    "RUS", "SWE", "SWZ", "USA",
]

fixtures = [
    "fixtures",
    "new_league_fixtures"
]

# %%
# DOWNLOAD COMPETITION DATA

# Base URL
base_url = 'https://www.football-data.co.uk/mmz4281/{}/{}.csv'

# Iterate over seasons and competition codes
for season in seasons:
    for comp in comps:
        # Construct file URL
        file_url = base_url.format(season, comp)
        
        # Set the path where the file will be saved
        save_path = f'data/scraped/{season}/{comp}.csv'
        
        # Ensure the directory exists
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        
        try:
            # Download the file
            response = requests.get(file_url)
            
            # Check if the response was successful
            if response.status_code == 200:
                # Write the content to the file, overwriting if it exists
                with open(save_path, 'wb') as file:
                    file.write(response.content)
                
                print(f'Successfully downloaded and saved: {save_path}')
            else:
                print(f'Failed to download {file_url}. Status code: {response.status_code}')
            
            # Wait for 1 second to avoid overwhelming the server
            #time.sleep(1)
        except Exception as e:
            print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# Successfully downloaded and saved: data/scraped/1516/E0.csv
# Successfully downloaded and saved: data/scraped/1516/E1.csv
# Successfully downloaded and saved: data/scraped/1516/E2.csv
# Successfully downloaded and saved: data/scraped/1516/E3.csv
# Successfully downloaded and saved: data/scraped/1516/SC0.csv
# Successfully downloaded and saved: data/scraped/1516/SC1.csv
# Successfully downloaded and saved: data/scraped/1516/D1.csv
# Successfully downloaded and saved: data/scraped/1516/D2.csv
# Successfully downloaded and saved: data/scraped/1516/F1.csv
# Successfully downloaded and saved: data/scraped/1516/F2.csv
# Successfully downloaded and saved: data/scraped/1516/I1.csv
# Successfully downloaded and saved: data/scraped/1516/I2.csv
# Successfully downloaded and saved: data/scraped/1516/SP1.csv
# Successfully downloaded and saved: data/scraped/1516/SP2.csv
# Successfully downloaded and saved: data/scraped/1516/B1.csv
# Successfully downloaded and saved: data/scraped/1516/G1.csv
# Successfully downloaded and saved: data/scraped/1516/N1.csv
# Successfully downloaded and saved: data/scraped/1516/P1.csv
# Successfully downloaded and saved: data/scraped/1516/T1.csv
# Successfully downloaded and saved: data/scraped/1415/E0.csv
# Successfully downloaded and saved: data/scraped/1415/E1.csv
# Successfully downloaded and saved: data/scraped/1415/E2.csv
# Successfully downloaded and saved: data/scraped/1415/E3.csv
# Successfully downloaded and saved: data/scraped/1415/SC0.csv
# Successfully downloaded and saved: data/scraped/1415/SC1.csv
# Successfully downloaded and saved: data/scraped/1415/D1.csv
# Successfully downloaded and saved: data/scraped/1415/D2.csv
# Successfully downloaded and saved: data/scraped/1415/F1.csv
# Successfully downloaded and saved: data/scraped/1415/F2.csv
# Successfully downloaded and saved: data/scraped/1415/I1.csv
# Successfully downloaded and saved: data/scraped/1415/I2.csv
# Successfully downloaded and saved: data/scraped/1415/SP1.csv
# Successfully downloaded and saved: data/scraped/1415/SP2.csv
# Successfully downloaded and saved: data/scraped/1415/B1.csv
# Successfully downloaded and saved: data/scraped/1415/G1.csv
# Successfully downloaded and saved: data/scraped/1415/N1.csv
# Successfully downloaded and saved: data/scraped/1415/P1.csv
# Successfully downloaded and saved: data/scraped/1415/T1.csv
# Successfully downloaded and saved: data/scraped/1314/E0.csv
# Successfully downloaded and saved: data/scraped/1314/E1.csv
# Successfully downloaded and saved: data/scraped/1314/E2.csv
# Successfully downloaded and saved: data/scraped/1314/E3.csv
# Successfully downloaded and saved: data/scraped/1314/SC0.csv
# Successfully downloaded and saved: data/scraped/1314/SC1.csv
# Successfully downloaded and saved: data/scraped/1314/D1.csv
# Successfully downloaded and saved: data/scraped/1314/D2.csv
# Successfully downloaded and saved: data/scraped/1314/F1.csv
# Successfully downloaded and saved: data/scraped/1314/F2.csv
# Successfully downloaded and saved: data/scraped/1314/I1.csv
# Successfully downloaded and saved: data/scraped/1314/I2.csv
# Successfully downloaded and saved: data/scraped/1314/SP1.csv
# Successfully downloaded and saved: data/scraped/1314/SP2.csv
# Successfully downloaded and saved: data/scraped/1314/B1.csv
# Successfully downloaded and saved: data/scraped/1314/G1.csv
# Successfully downloaded and saved: data/scraped/1314/N1.csv
# Successfully downloaded and saved: data/scraped/1314/P1.csv
# Successfully downloaded and saved: data/scraped/1314/T1.csv
# Successfully downloaded and saved: data/scraped/1213/E0.csv
# Successfully downloaded and saved: data/scraped/1213/E1.csv
# Successfully downloaded and saved: data/scraped/1213/E2.csv
# Successfully downloaded and saved: data/scraped/1213/E3.csv
# Successfully downloaded and saved: data/scraped/1213/SC0.csv
# Successfully downloaded and saved: data/scraped/1213/SC1.csv
# Successfully downloaded and saved: data/scraped/1213/D1.csv
# Successfully downloaded and saved: data/scraped/1213/D2.csv
# Successfully downloaded and saved: data/scraped/1213/F1.csv
# Successfully downloaded and saved: data/scraped/1213/F2.csv
# Successfully downloaded and saved: data/scraped/1213/I1.csv
# Successfully downloaded and saved: data/scraped/1213/I2.csv
# Successfully downloaded and saved: data/scraped/1213/SP1.csv
# Successfully downloaded and saved: data/scraped/1213/SP2.csv
# Successfully downloaded and saved: data/scraped/1213/B1.csv
# Successfully downloaded and saved: data/scraped/1213/G1.csv
# Successfully downloaded and saved: data/scraped/1213/N1.csv
# Successfully downloaded and saved: data/scraped/1213/P1.csv
# Successfully downloaded and saved: data/scraped/1213/T1.csv
# Successfully downloaded and saved: data/scraped/1112/E0.csv
# Successfully downloaded and saved: data/scraped/1112/E1.csv
# Successfully downloaded and saved: data/scraped/1112/E2.csv
# Successfully downloaded and saved: data/scraped/1112/E3.csv
# Successfully downloaded and saved: data/scraped/1112/SC0.csv
# Successfully downloaded and saved: data/scraped/1112/SC1.csv
# Successfully downloaded and saved: data/scraped/1112/D1.csv
# Successfully downloaded and saved: data/scraped/1112/D2.csv
# Successfully downloaded and saved: data/scraped/1112/F1.csv
# Successfully downloaded and saved: data/scraped/1112/F2.csv
# Successfully downloaded and saved: data/scraped/1112/I1.csv
# Successfully downloaded and saved: data/scraped/1112/I2.csv
# Successfully downloaded and saved: data/scraped/1112/SP1.csv
# Successfully downloaded and saved: data/scraped/1112/SP2.csv
# Successfully downloaded and saved: data/scraped/1112/B1.csv
# Successfully downloaded and saved: data/scraped/1112/G1.csv
# Successfully downloaded and saved: data/scraped/1112/N1.csv
# Successfully downloaded and saved: data/scraped/1112/P1.csv
# Successfully downloaded and saved: data/scraped/1112/T1.csv
# Successfully downloaded and saved: data/scraped/1011/E0.csv
# Successfully downloaded and saved: data/scraped/1011/E1.csv
# Successfully downloaded and saved: data/scraped/1011/E2.csv
# Successfully downloaded and saved: data/scraped/1011/E3.csv
# Successfully downloaded and saved: data/scraped/1011/SC0.csv
# Successfully downloaded and saved: data/scraped/1011/SC1.csv
# Successfully downloaded and saved: data/scraped/1011/D1.csv
# Successfully downloaded and saved: data/scraped/1011/D2.csv
# Successfully downloaded and saved: data/scraped/1011/F1.csv
# Successfully downloaded and saved: data/scraped/1011/F2.csv
# Successfully downloaded and saved: data/scraped/1011/I1.csv
# Successfully downloaded and saved: data/scraped/1011/I2.csv
# Successfully downloaded and saved: data/scraped/1011/SP1.csv
# Successfully downloaded and saved: data/scraped/1011/SP2.csv
# Successfully downloaded and saved: data/scraped/1011/B1.csv
# Successfully downloaded and saved: data/scraped/1011/G1.csv
# Successfully downloaded and saved: data/scraped/1011/N1.csv
# Successfully downloaded and saved: data/scraped/1011/P1.csv
# Successfully downloaded and saved: data/scraped/1011/T1.csv
# Successfully downloaded and saved: data/scraped/0910/E0.csv
# Successfully downloaded and saved: data/scraped/0910/E1.csv
# Successfully downloaded and saved: data/scraped/0910/E2.csv
# Successfully downloaded and saved: data/scraped/0910/E3.csv
# Successfully downloaded and saved: data/scraped/0910/SC0.csv
# Successfully downloaded and saved: data/scraped/0910/SC1.csv
# Successfully downloaded and saved: data/scraped/0910/D1.csv
# Successfully downloaded and saved: data/scraped/0910/D2.csv
# Successfully downloaded and saved: data/scraped/0910/F1.csv
# Successfully downloaded and saved: data/scraped/0910/F2.csv
# Successfully downloaded and saved: data/scraped/0910/I1.csv
# Successfully downloaded and saved: data/scraped/0910/I2.csv
# Successfully downloaded and saved: data/scraped/0910/SP1.csv
# Successfully downloaded and saved: data/scraped/0910/SP2.csv
# Successfully downloaded and saved: data/scraped/0910/B1.csv
# Successfully downloaded and saved: data/scraped/0910/G1.csv
# Successfully downloaded and saved: data/scraped/0910/N1.csv
# Successfully downloaded and saved: data/scraped/0910/P1.csv
# Successfully downloaded and saved: data/scraped/0910/T1.csv
# Successfully downloaded and saved: data/scraped/0809/E0.csv
# Successfully downloaded and saved: data/scraped/0809/E1.csv
# Successfully downloaded and saved: data/scraped/0809/E2.csv
# Successfully downloaded and saved: data/scraped/0809/E3.csv
# Successfully downloaded and saved: data/scraped/0809/SC0.csv
# Successfully downloaded and saved: data/scraped/0809/SC1.csv
# Successfully downloaded and saved: data/scraped/0809/D1.csv
# Successfully downloaded and saved: data/scraped/0809/D2.csv
# Successfully downloaded and saved: data/scraped/0809/F1.csv
# Successfully downloaded and saved: data/scraped/0809/F2.csv
# Successfully downloaded and saved: data/scraped/0809/I1.csv
# Successfully downloaded and saved: data/scraped/0809/I2.csv
# Successfully downloaded and saved: data/scraped/0809/SP1.csv
# Successfully downloaded and saved: data/scraped/0809/SP2.csv
# Successfully downloaded and saved: data/scraped/0809/B1.csv
# Successfully downloaded and saved: data/scraped/0809/G1.csv
# Successfully downloaded and saved: data/scraped/0809/N1.csv
# Successfully downloaded and saved: data/scraped/0809/P1.csv
# Successfully downloaded and saved: data/scraped/0809/T1.csv
# Successfully downloaded and saved: data/scraped/0708/E0.csv
# Successfully downloaded and saved: data/scraped/0708/E1.csv
# Successfully downloaded and saved: data/scraped/0708/E2.csv
# Successfully downloaded and saved: data/scraped/0708/E3.csv
# Successfully downloaded and saved: data/scraped/0708/SC0.csv
# Successfully downloaded and saved: data/scraped/0708/SC1.csv
# Successfully downloaded and saved: data/scraped/0708/D1.csv
# Successfully downloaded and saved: data/scraped/0708/D2.csv
# Successfully downloaded and saved: data/scraped/0708/F1.csv
# Successfully downloaded and saved: data/scraped/0708/F2.csv
# Successfully downloaded and saved: data/scraped/0708/I1.csv
# Successfully downloaded and saved: data/scraped/0708/I2.csv
# Successfully downloaded and saved: data/scraped/0708/SP1.csv
# Successfully downloaded and saved: data/scraped/0708/SP2.csv
# Successfully downloaded and saved: data/scraped/0708/B1.csv
# Successfully downloaded and saved: data/scraped/0708/G1.csv
# Successfully downloaded and saved: data/scraped/0708/N1.csv
# Successfully downloaded and saved: data/scraped/0708/P1.csv
# Successfully downloaded and saved: data/scraped/0708/T1.csv
# Successfully downloaded and saved: data/scraped/0607/E0.csv
# Successfully downloaded and saved: data/scraped/0607/E1.csv
# Successfully downloaded and saved: data/scraped/0607/E2.csv
# Successfully downloaded and saved: data/scraped/0607/E3.csv
# Successfully downloaded and saved: data/scraped/0607/SC0.csv
# Successfully downloaded and saved: data/scraped/0607/SC1.csv
# Successfully downloaded and saved: data/scraped/0607/D1.csv
# Successfully downloaded and saved: data/scraped/0607/D2.csv
# Successfully downloaded and saved: data/scraped/0607/F1.csv
# Successfully downloaded and saved: data/scraped/0607/F2.csv
# Successfully downloaded and saved: data/scraped/0607/I1.csv
# Successfully downloaded and saved: data/scraped/0607/I2.csv
# Successfully downloaded and saved: data/scraped/0607/SP1.csv
# Successfully downloaded and saved: data/scraped/0607/SP2.csv
# Successfully downloaded and saved: data/scraped/0607/B1.csv
# Successfully downloaded and saved: data/scraped/0607/G1.csv
# Successfully downloaded and saved: data/scraped/0607/N1.csv
# Successfully downloaded and saved: data/scraped/0607/P1.csv
# Successfully downloaded and saved: data/scraped/0607/T1.csv
# Successfully downloaded and saved: data/scraped/0506/E0.csv
# Successfully downloaded and saved: data/scraped/0506/E1.csv
# Successfully downloaded and saved: data/scraped/0506/E2.csv
# Successfully downloaded and saved: data/scraped/0506/E3.csv
# Successfully downloaded and saved: data/scraped/0506/SC0.csv
# Successfully downloaded and saved: data/scraped/0506/SC1.csv
# Successfully downloaded and saved: data/scraped/0506/D1.csv
# Successfully downloaded and saved: data/scraped/0506/D2.csv
# Successfully downloaded and saved: data/scraped/0506/F1.csv
# Successfully downloaded and saved: data/scraped/0506/F2.csv
# Successfully downloaded and saved: data/scraped/0506/I1.csv
# Successfully downloaded and saved: data/scraped/0506/I2.csv
# Successfully downloaded and saved: data/scraped/0506/SP1.csv
# Successfully downloaded and saved: data/scraped/0506/SP2.csv
# Successfully downloaded and saved: data/scraped/0506/B1.csv
# Successfully downloaded and saved: data/scraped/0506/G1.csv
# Successfully downloaded and saved: data/scraped/0506/N1.csv
# Successfully downloaded and saved: data/scraped/0506/P1.csv
# Successfully downloaded and saved: data/scraped/0506/T1.csv
# Successfully downloaded and saved: data/scraped/0405/E0.csv
# Successfully downloaded and saved: data/scraped/0405/E1.csv
# Successfully downloaded and saved: data/scraped/0405/E2.csv
# Successfully downloaded and saved: data/scraped/0405/E3.csv
# Successfully downloaded and saved: data/scraped/0405/SC0.csv
# Successfully downloaded and saved: data/scraped/0405/SC1.csv
# Successfully downloaded and saved: data/scraped/0405/D1.csv
# Successfully downloaded and saved: data/scraped/0405/D2.csv
# Successfully downloaded and saved: data/scraped/0405/F1.csv
# Successfully downloaded and saved: data/scraped/0405/F2.csv
# Successfully downloaded and saved: data/scraped/0405/I1.csv
# Successfully downloaded and saved: data/scraped/0405/I2.csv
# Successfully downloaded and saved: data/scraped/0405/SP1.csv
# Successfully downloaded and saved: data/scraped/0405/SP2.csv
# Successfully downloaded and saved: data/scraped/0405/B1.csv
# Successfully downloaded and saved: data/scraped/0405/G1.csv
# Successfully downloaded and saved: data/scraped/0405/N1.csv
# Successfully downloaded and saved: data/scraped/0405/P1.csv
# Successfully downloaded and saved: data/scraped/0405/T1.csv
# Successfully downloaded and saved: data/scraped/0304/E0.csv
# Successfully downloaded and saved: data/scraped/0304/E1.csv
# Successfully downloaded and saved: data/scraped/0304/E2.csv
# Successfully downloaded and saved: data/scraped/0304/E3.csv
# Successfully downloaded and saved: data/scraped/0304/SC0.csv
# Successfully downloaded and saved: data/scraped/0304/SC1.csv
# Successfully downloaded and saved: data/scraped/0304/D1.csv
# Successfully downloaded and saved: data/scraped/0304/D2.csv
# Successfully downloaded and saved: data/scraped/0304/F1.csv
# Successfully downloaded and saved: data/scraped/0304/F2.csv
# Successfully downloaded and saved: data/scraped/0304/I1.csv
# Successfully downloaded and saved: data/scraped/0304/I2.csv
# Successfully downloaded and saved: data/scraped/0304/SP1.csv
# Successfully downloaded and saved: data/scraped/0304/SP2.csv
# Successfully downloaded and saved: data/scraped/0304/B1.csv
# Successfully downloaded and saved: data/scraped/0304/G1.csv
# Successfully downloaded and saved: data/scraped/0304/N1.csv
# Successfully downloaded and saved: data/scraped/0304/P1.csv
# Successfully downloaded and saved: data/scraped/0304/T1.csv
# Successfully downloaded and saved: data/scraped/0203/E0.csv
# Successfully downloaded and saved: data/scraped/0203/E1.csv
# Successfully downloaded and saved: data/scraped/0203/E2.csv
# Successfully downloaded and saved: data/scraped/0203/E3.csv
# Successfully downloaded and saved: data/scraped/0203/SC0.csv
# Successfully downloaded and saved: data/scraped/0203/SC1.csv
# Successfully downloaded and saved: data/scraped/0203/D1.csv
# Successfully downloaded and saved: data/scraped/0203/D2.csv
# Successfully downloaded and saved: data/scraped/0203/F1.csv
# Successfully downloaded and saved: data/scraped/0203/F2.csv
# Successfully downloaded and saved: data/scraped/0203/I1.csv
# Successfully downloaded and saved: data/scraped/0203/I2.csv
# Successfully downloaded and saved: data/scraped/0203/SP1.csv
# Successfully downloaded and saved: data/scraped/0203/SP2.csv
# Successfully downloaded and saved: data/scraped/0203/B1.csv
# Successfully downloaded and saved: data/scraped/0203/G1.csv
# Successfully downloaded and saved: data/scraped/0203/N1.csv
# Successfully downloaded and saved: data/scraped/0203/P1.csv
# Successfully downloaded and saved: data/scraped/0203/T1.csv
# Successfully downloaded and saved: data/scraped/0102/E0.csv
# Successfully downloaded and saved: data/scraped/0102/E1.csv
# Successfully downloaded and saved: data/scraped/0102/E2.csv
# Successfully downloaded and saved: data/scraped/0102/E3.csv
# Successfully downloaded and saved: data/scraped/0102/SC0.csv
# Successfully downloaded and saved: data/scraped/0102/SC1.csv
# Successfully downloaded and saved: data/scraped/0102/D1.csv
# Successfully downloaded and saved: data/scraped/0102/D2.csv
# Successfully downloaded and saved: data/scraped/0102/F1.csv
# Successfully downloaded and saved: data/scraped/0102/F2.csv
# Successfully downloaded and saved: data/scraped/0102/I1.csv
# Successfully downloaded and saved: data/scraped/0102/I2.csv
# Successfully downloaded and saved: data/scraped/0102/SP1.csv
# Successfully downloaded and saved: data/scraped/0102/SP2.csv
# Successfully downloaded and saved: data/scraped/0102/B1.csv
# Successfully downloaded and saved: data/scraped/0102/G1.csv
# Successfully downloaded and saved: data/scraped/0102/N1.csv
# Successfully downloaded and saved: data/scraped/0102/P1.csv
# Successfully downloaded and saved: data/scraped/0102/T1.csv
# Successfully downloaded and saved: data/scraped/0001/E0.csv
# Successfully downloaded and saved: data/scraped/0001/E1.csv
# Successfully downloaded and saved: data/scraped/0001/E2.csv
# Successfully downloaded and saved: data/scraped/0001/E3.csv
# Successfully downloaded and saved: data/scraped/0001/SC0.csv
# Successfully downloaded and saved: data/scraped/0001/SC1.csv
# Successfully downloaded and saved: data/scraped/0001/D1.csv
# Successfully downloaded and saved: data/scraped/0001/D2.csv
# Successfully downloaded and saved: data/scraped/0001/F1.csv
# Successfully downloaded and saved: data/scraped/0001/F2.csv
# Successfully downloaded and saved: data/scraped/0001/I1.csv
# Successfully downloaded and saved: data/scraped/0001/I2.csv
# Successfully downloaded and saved: data/scraped/0001/SP1.csv
# Successfully downloaded and saved: data/scraped/0001/SP2.csv
# Successfully downloaded and saved: data/scraped/0001/B1.csv
# Successfully downloaded and saved: data/scraped/0001/G1.csv
# Successfully downloaded and saved: data/scraped/0001/N1.csv
# Successfully downloaded and saved: data/scraped/0001/P1.csv
# Successfully downloaded and saved: data/scraped/0001/T1.csv

# %%
# DOWNLOAD COUNTRY DATA

# Base URL
base_url = 'https://www.football-data.co.uk/new/{}.csv'


for country in countries:
    # Construct file URL
    file_url = base_url.format(country)
    
    # Set the path where the file will be saved
    save_path = f'data/scraped/other/{country}.csv'
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    try:
        # Download the file
        response = requests.get(file_url)
        
        # Check if the response was successful
        if response.status_code == 200:
            # Write the content to the file, overwriting if it exists
            with open(save_path, 'wb') as file:
                file.write(response.content)
            
            print(f'Successfully downloaded and saved: {save_path}')
        else:
            print(f'Failed to download {file_url}. Status code: {response.status_code}')
        
        # Wait for 1 second to avoid overwhelming the server
        #time.sleep(1)
    except Exception as e:
        print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# Successfully downloaded and saved: data/scraped/other/ARG.csv
# Successfully downloaded and saved: data/scraped/other/AUT.csv
# Successfully downloaded and saved: data/scraped/other/BRA.csv
# Successfully downloaded and saved: data/scraped/other/CHN.csv
# Successfully downloaded and saved: data/scraped/other/DNK.csv
# Successfully downloaded and saved: data/scraped/other/FIN.csv
# Successfully downloaded and saved: data/scraped/other/IRL.csv
# Successfully downloaded and saved: data/scraped/other/JPN.csv
# Successfully downloaded and saved: data/scraped/other/MEX.csv
# Successfully downloaded and saved: data/scraped/other/NOR.csv
# Successfully downloaded and saved: data/scraped/other/POL.csv
# Successfully downloaded and saved: data/scraped/other/ROU.csv
# Successfully downloaded and saved: data/scraped/other/RUS.csv
# Successfully downloaded and saved: data/scraped/other/SWE.csv
# Successfully downloaded and saved: data/scraped/other/SWZ.csv
# Successfully downloaded and saved: data/scraped/other/USA.csv

# %%
# DOWNLOAD FIXTURE DATA

# Base URL
base_url = 'https://www.football-data.co.uk/'


for fixture in fixtures:
    
    # Construct file URL
    file_url = base_url.format(fixture)
    
    # Set the path where the file will be saved
    save_path = f'data/scraped/fixtures/{fixture}.csv'
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    try:
        # Download the file
        response = requests.get(file_url)
        
        # Check if the response was successful
        if response.status_code == 200:
            # Write the content to the file, overwriting if it exists
            with open(save_path, 'wb') as file:
                file.write(response.content)
            
            print(f'Successfully downloaded and saved: {save_path}')
        else:
            print(f'Failed to download {file_url}. Status code: {response.status_code}')
        
        # Wait for 1 second to avoid overwhelming the server
        #time.sleep(1)
    except Exception as e:
        print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# Successfully downloaded and saved: data/scraped/fixtures/fixtures.csv
# Successfully downloaded and saved: data/scraped/fixtures/new_league_fixtures.csv
