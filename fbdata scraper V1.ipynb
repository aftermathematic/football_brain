# %%
# Standard library imports
import os
import warnings
import requests
import time

# Miscellaneous settings
# %matplotlib inline
warnings.filterwarnings('ignore')

# %%
comps = [
    'E0', 'E1', 'E2', 'E3',
    'SC0', 'SC1',
    'D1', 'D2',
    'F1', 'F2',
    'I1', 'I2',
    'SP1', 'SP2',
    'B1',
    'G1',
    'N1',
    'P1',
    'T1',
]

seasons = [
    #'2324', 
    #'2223', '2122', '2021',
    '1920', '1819', '1718', '1617',
    '1516', '1415', '1314', '1213',
    #'1112', '1011', 
    #'0910', '0809',
    #'0708', '0607', '0506', '0405',
    #'0304', '0203', '0102', '0001',
]


countries = [
    "ARG", "AUT", "BRA", "CHN",
    "DNK", "FIN", "IRL", "JPN",
    "MEX", "NOR", "POL", "ROU",
    "RUS", "SWE", "SWZ", "USA",
]

fixtures = [
    "fixtures",
    "new_league_fixtures"
]

# %%
# DOWNLOAD COMPETITION DATA

# Base URL
base_url = 'https://www.football-data.co.uk/mmz4281/{}/{}.csv'

# Iterate over seasons and competition codes
for season in seasons:
    for comp in comps:
        # Construct file URL
        file_url = base_url.format(season, comp)
        
        # Set the path where the file will be saved
        save_path = f'data/scraped/{season}/{comp}.csv'
        
        # Ensure the directory exists
        os.makedirs(os.path.dirname(save_path), exist_ok=True)
        
        try:
            # Download the file
            response = requests.get(file_url)
            
            # Check if the response was successful
            if response.status_code == 200:
                # Write the content to the file, overwriting if it exists
                with open(save_path, 'wb') as file:
                    file.write(response.content)
                
                print(f'Successfully downloaded and saved: {save_path}')
            else:
                print(f'Failed to download {file_url}. Status code: {response.status_code}')
            
            # Wait for 1 second to avoid overwhelming the server
            #time.sleep(1)
        except Exception as e:
            print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# Successfully downloaded and saved: data/scraped/1920/E0.csv
# Successfully downloaded and saved: data/scraped/1920/E1.csv
# Successfully downloaded and saved: data/scraped/1920/E2.csv
# Successfully downloaded and saved: data/scraped/1920/E3.csv
# Successfully downloaded and saved: data/scraped/1920/SC0.csv
# Successfully downloaded and saved: data/scraped/1920/SC1.csv
# Successfully downloaded and saved: data/scraped/1920/D1.csv
# Successfully downloaded and saved: data/scraped/1920/D2.csv
# Successfully downloaded and saved: data/scraped/1920/F1.csv
# Successfully downloaded and saved: data/scraped/1920/F2.csv
# Successfully downloaded and saved: data/scraped/1920/I1.csv
# Successfully downloaded and saved: data/scraped/1920/I2.csv
# Successfully downloaded and saved: data/scraped/1920/SP1.csv
# Successfully downloaded and saved: data/scraped/1920/SP2.csv
# Successfully downloaded and saved: data/scraped/1920/B1.csv
# Successfully downloaded and saved: data/scraped/1920/G1.csv
# Successfully downloaded and saved: data/scraped/1920/N1.csv
# Successfully downloaded and saved: data/scraped/1920/P1.csv
# Successfully downloaded and saved: data/scraped/1920/T1.csv
# Successfully downloaded and saved: data/scraped/1819/E0.csv
# Successfully downloaded and saved: data/scraped/1819/E1.csv
# Successfully downloaded and saved: data/scraped/1819/E2.csv
# Successfully downloaded and saved: data/scraped/1819/E3.csv
# Successfully downloaded and saved: data/scraped/1819/SC0.csv
# Successfully downloaded and saved: data/scraped/1819/SC1.csv
# Successfully downloaded and saved: data/scraped/1819/D1.csv
# Successfully downloaded and saved: data/scraped/1819/D2.csv
# Successfully downloaded and saved: data/scraped/1819/F1.csv
# Successfully downloaded and saved: data/scraped/1819/F2.csv
# Successfully downloaded and saved: data/scraped/1819/I1.csv
# Successfully downloaded and saved: data/scraped/1819/I2.csv
# Successfully downloaded and saved: data/scraped/1819/SP1.csv
# Successfully downloaded and saved: data/scraped/1819/SP2.csv
# Successfully downloaded and saved: data/scraped/1819/B1.csv
# Successfully downloaded and saved: data/scraped/1819/G1.csv
# Successfully downloaded and saved: data/scraped/1819/N1.csv
# Successfully downloaded and saved: data/scraped/1819/P1.csv
# Successfully downloaded and saved: data/scraped/1819/T1.csv
# Successfully downloaded and saved: data/scraped/1718/E0.csv
# Successfully downloaded and saved: data/scraped/1718/E1.csv
# Successfully downloaded and saved: data/scraped/1718/E2.csv
# Successfully downloaded and saved: data/scraped/1718/E3.csv
# Successfully downloaded and saved: data/scraped/1718/SC0.csv
# Successfully downloaded and saved: data/scraped/1718/SC1.csv
# Successfully downloaded and saved: data/scraped/1718/D1.csv
# Successfully downloaded and saved: data/scraped/1718/D2.csv
# Successfully downloaded and saved: data/scraped/1718/F1.csv
# Successfully downloaded and saved: data/scraped/1718/F2.csv
# Successfully downloaded and saved: data/scraped/1718/I1.csv
# Successfully downloaded and saved: data/scraped/1718/I2.csv
# Successfully downloaded and saved: data/scraped/1718/SP1.csv
# Successfully downloaded and saved: data/scraped/1718/SP2.csv
# Successfully downloaded and saved: data/scraped/1718/B1.csv
# Successfully downloaded and saved: data/scraped/1718/G1.csv
# Successfully downloaded and saved: data/scraped/1718/N1.csv
# Successfully downloaded and saved: data/scraped/1718/P1.csv
# Successfully downloaded and saved: data/scraped/1718/T1.csv
# Successfully downloaded and saved: data/scraped/1617/E0.csv
# Successfully downloaded and saved: data/scraped/1617/E1.csv
# Successfully downloaded and saved: data/scraped/1617/E2.csv
# Successfully downloaded and saved: data/scraped/1617/E3.csv
# Successfully downloaded and saved: data/scraped/1617/SC0.csv
# Successfully downloaded and saved: data/scraped/1617/SC1.csv
# Successfully downloaded and saved: data/scraped/1617/D1.csv
# Successfully downloaded and saved: data/scraped/1617/D2.csv
# Successfully downloaded and saved: data/scraped/1617/F1.csv
# Successfully downloaded and saved: data/scraped/1617/F2.csv
# Successfully downloaded and saved: data/scraped/1617/I1.csv
# Successfully downloaded and saved: data/scraped/1617/I2.csv
# Successfully downloaded and saved: data/scraped/1617/SP1.csv
# Successfully downloaded and saved: data/scraped/1617/SP2.csv
# Successfully downloaded and saved: data/scraped/1617/B1.csv
# Successfully downloaded and saved: data/scraped/1617/G1.csv
# Successfully downloaded and saved: data/scraped/1617/N1.csv
# Successfully downloaded and saved: data/scraped/1617/P1.csv
# Successfully downloaded and saved: data/scraped/1617/T1.csv
# Successfully downloaded and saved: data/scraped/1516/E0.csv
# Successfully downloaded and saved: data/scraped/1516/E1.csv
# Successfully downloaded and saved: data/scraped/1516/E2.csv
# Successfully downloaded and saved: data/scraped/1516/E3.csv
# Successfully downloaded and saved: data/scraped/1516/SC0.csv
# Successfully downloaded and saved: data/scraped/1516/SC1.csv
# Successfully downloaded and saved: data/scraped/1516/D1.csv
# Successfully downloaded and saved: data/scraped/1516/D2.csv
# Successfully downloaded and saved: data/scraped/1516/F1.csv
# Successfully downloaded and saved: data/scraped/1516/F2.csv
# Successfully downloaded and saved: data/scraped/1516/I1.csv
# Successfully downloaded and saved: data/scraped/1516/I2.csv
# Successfully downloaded and saved: data/scraped/1516/SP1.csv
# Successfully downloaded and saved: data/scraped/1516/SP2.csv
# Successfully downloaded and saved: data/scraped/1516/B1.csv
# Successfully downloaded and saved: data/scraped/1516/G1.csv
# Successfully downloaded and saved: data/scraped/1516/N1.csv
# Successfully downloaded and saved: data/scraped/1516/P1.csv
# Successfully downloaded and saved: data/scraped/1516/T1.csv
# Successfully downloaded and saved: data/scraped/1415/E0.csv
# Successfully downloaded and saved: data/scraped/1415/E1.csv
# Successfully downloaded and saved: data/scraped/1415/E2.csv
# Successfully downloaded and saved: data/scraped/1415/E3.csv
# Successfully downloaded and saved: data/scraped/1415/SC0.csv
# Successfully downloaded and saved: data/scraped/1415/SC1.csv
# Successfully downloaded and saved: data/scraped/1415/D1.csv
# Successfully downloaded and saved: data/scraped/1415/D2.csv
# Successfully downloaded and saved: data/scraped/1415/F1.csv
# Successfully downloaded and saved: data/scraped/1415/F2.csv
# Successfully downloaded and saved: data/scraped/1415/I1.csv
# Successfully downloaded and saved: data/scraped/1415/I2.csv
# Successfully downloaded and saved: data/scraped/1415/SP1.csv
# Successfully downloaded and saved: data/scraped/1415/SP2.csv
# Successfully downloaded and saved: data/scraped/1415/B1.csv
# Successfully downloaded and saved: data/scraped/1415/G1.csv
# Successfully downloaded and saved: data/scraped/1415/N1.csv
# Successfully downloaded and saved: data/scraped/1415/P1.csv
# Successfully downloaded and saved: data/scraped/1415/T1.csv
# Successfully downloaded and saved: data/scraped/1314/E0.csv
# Successfully downloaded and saved: data/scraped/1314/E1.csv
# Successfully downloaded and saved: data/scraped/1314/E2.csv
# Successfully downloaded and saved: data/scraped/1314/E3.csv
# Successfully downloaded and saved: data/scraped/1314/SC0.csv
# Successfully downloaded and saved: data/scraped/1314/SC1.csv
# Successfully downloaded and saved: data/scraped/1314/D1.csv
# Successfully downloaded and saved: data/scraped/1314/D2.csv
# Successfully downloaded and saved: data/scraped/1314/F1.csv
# Successfully downloaded and saved: data/scraped/1314/F2.csv
# Successfully downloaded and saved: data/scraped/1314/I1.csv
# Successfully downloaded and saved: data/scraped/1314/I2.csv
# Successfully downloaded and saved: data/scraped/1314/SP1.csv
# Successfully downloaded and saved: data/scraped/1314/SP2.csv
# Successfully downloaded and saved: data/scraped/1314/B1.csv
# Successfully downloaded and saved: data/scraped/1314/G1.csv
# Successfully downloaded and saved: data/scraped/1314/N1.csv
# Successfully downloaded and saved: data/scraped/1314/P1.csv
# Successfully downloaded and saved: data/scraped/1314/T1.csv
# Successfully downloaded and saved: data/scraped/1213/E0.csv
# Successfully downloaded and saved: data/scraped/1213/E1.csv
# Successfully downloaded and saved: data/scraped/1213/E2.csv
# Successfully downloaded and saved: data/scraped/1213/E3.csv
# Successfully downloaded and saved: data/scraped/1213/SC0.csv
# Successfully downloaded and saved: data/scraped/1213/SC1.csv
# Successfully downloaded and saved: data/scraped/1213/D1.csv
# Successfully downloaded and saved: data/scraped/1213/D2.csv
# Successfully downloaded and saved: data/scraped/1213/F1.csv
# Successfully downloaded and saved: data/scraped/1213/F2.csv
# Successfully downloaded and saved: data/scraped/1213/I1.csv
# Successfully downloaded and saved: data/scraped/1213/I2.csv
# Successfully downloaded and saved: data/scraped/1213/SP1.csv
# Successfully downloaded and saved: data/scraped/1213/SP2.csv
# Successfully downloaded and saved: data/scraped/1213/B1.csv
# Successfully downloaded and saved: data/scraped/1213/G1.csv
# Successfully downloaded and saved: data/scraped/1213/N1.csv
# Successfully downloaded and saved: data/scraped/1213/P1.csv
# Successfully downloaded and saved: data/scraped/1213/T1.csv

# %%
# DOWNLOAD COUNTRY DATA

# Base URL
base_url = 'https://www.football-data.co.uk/new/{}.csv'


for country in countries:
    # Construct file URL
    file_url = base_url.format(country)
    
    # Set the path where the file will be saved
    save_path = f'data/scraped/other/{country}.csv'
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    try:
        # Download the file
        response = requests.get(file_url)
        
        # Check if the response was successful
        if response.status_code == 200:
            # Write the content to the file, overwriting if it exists
            with open(save_path, 'wb') as file:
                file.write(response.content)
            
            print(f'Successfully downloaded and saved: {save_path}')
        else:
            print(f'Failed to download {file_url}. Status code: {response.status_code}')
        
        # Wait for 1 second to avoid overwhelming the server
        #time.sleep(1)
    except Exception as e:
        print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# Successfully downloaded and saved: data/scraped/other/ARG.csv
# Successfully downloaded and saved: data/scraped/other/AUT.csv
# Successfully downloaded and saved: data/scraped/other/BRA.csv
# Successfully downloaded and saved: data/scraped/other/CHN.csv
# Successfully downloaded and saved: data/scraped/other/DNK.csv
# Successfully downloaded and saved: data/scraped/other/FIN.csv
# Successfully downloaded and saved: data/scraped/other/IRL.csv
# Successfully downloaded and saved: data/scraped/other/JPN.csv
# Successfully downloaded and saved: data/scraped/other/MEX.csv
# Successfully downloaded and saved: data/scraped/other/NOR.csv
# Successfully downloaded and saved: data/scraped/other/POL.csv
# Successfully downloaded and saved: data/scraped/other/ROU.csv
# Successfully downloaded and saved: data/scraped/other/RUS.csv
# Successfully downloaded and saved: data/scraped/other/SWE.csv
# Successfully downloaded and saved: data/scraped/other/SWZ.csv
# Successfully downloaded and saved: data/scraped/other/USA.csv

# %%
# DOWNLOAD FIXTURE DATA

# Base URL
base_url = 'https://www.football-data.co.uk/{}.csv'


for fixture in fixtures:
    
    # Construct file URL
    file_url = base_url.format(fixture)

    print(file_url)
    
    # Set the path where the file will be saved
    save_path = f'data/scraped/{seasons[0]}/{fixture}.csv'
    
    # Ensure the directory exists
    os.makedirs(os.path.dirname(save_path), exist_ok=True)
    
    try:
        # Download the file
        response = requests.get(file_url)
        
        # Check if the response was successful
        if response.status_code == 200:
            # Write the content to the file, overwriting if it exists
            with open(save_path, 'wb') as file:
                file.write(response.content)
            
            print(f'Successfully downloaded and saved: {save_path}')
        else:
            print(f'Failed to download {file_url}. Status code: {response.status_code}')
        
        # Wait for 1 second to avoid overwhelming the server
        #time.sleep(1)
    except Exception as e:
        print(f'An error occurred while downloading {file_url}: {e}')
# Out:
# https://www.football-data.co.uk/fixtures.csv
# Successfully downloaded and saved: data/scraped/1920/fixtures.csv
# https://www.football-data.co.uk/new_league_fixtures.csv
# Successfully downloaded and saved: data/scraped/1920/new_league_fixtures.csv

# %%
import winsound
frequency = 400  # Set Frequency To 2500 Hertz
duration = 200  # Set Duration To 1000 ms == 1 second
winsound.Beep(frequency, duration)
